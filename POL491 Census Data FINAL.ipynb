# %%
pip install census
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install states
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install us
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import nltk
import sklearn
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import sqlalchemy
import json

# %%
from census import Census
from us import states

# Replace 'YOUR_API_KEY' with your actual Census Bureau API key
c = Census("592f0805f7272e17ae1074a319623453d829ef2d")

# Example: Fetch median household income by state for 2019
income_data2019 = c.acs5.state(('NAME', 'B19013_001E'), Census.ALL, year=2019)

# Convert to a DataFrame for easier analysis
income_df2019 = pd.DataFrame(income_data2019)

# Rename columns for clarity
income_df2019.rename(columns={'NAME': 'State', 'B19013_001E': 'Median Household Income'}, inplace=True)

print(income_df2019)
# Out:
#                    State  Median Household Income state
# 0                Alabama                  50536.0    01
# 1                 Alaska                  77640.0    02
# 2                Arizona                  58945.0    04
# 3               Arkansas                  47597.0    05
# 4             California                  75235.0    06
# 5               Colorado                  72331.0    08
# 6               Delaware                  68287.0    10
# 7   District of Columbia                  86420.0    11
# 8            Connecticut                  78444.0    09
# 9                Florida                  55660.0    12
# 10               Georgia                  58700.0    13
# 11                 Idaho                  55785.0    16
# 12                Hawaii                  81275.0    15
# 13              Illinois                  65886.0    17
# 14               Indiana                  56303.0    18
# 15                  Iowa                  60523.0    19
# ...

# %%
# Replace 'YOUR_API_KEY' with your actual Census Bureau API key
c = Census("API KEY")

# Example: Fetch median household income by state for 2019
income_data2018 = c.acs5.state(('NAME', 'B19013_001E'), Census.ALL, year=2018)

# Convert to a DataFrame for easier analysis
income_df2018 = pd.DataFrame(income_data2018)

# Rename columns for clarity
income_df2018.rename(columns={'NAME': 'State', 'B19013_001E': 'Median Household Income'}, inplace=True)

print(income_df2018)
# Out:
#                    State  Median Household Income state
# 0            Mississippi                  43567.0    28
# 1               Missouri                  53560.0    29
# 2                Montana                  52559.0    30
# 3               Nebraska                  59116.0    31
# 4                 Nevada                  57598.0    32
# 5          New Hampshire                  74057.0    33
# 6             New Jersey                  79363.0    34
# 7             New Mexico                  48059.0    35
# 8               New York                  65323.0    36
# 9         North Carolina                  52413.0    37
# 10          North Dakota                  63473.0    38
# 11                  Ohio                  54533.0    39
# 12              Oklahoma                  51424.0    40
# 13                Oregon                  59393.0    41
# 14          Pennsylvania                  59445.0    42
# 15          Rhode Island                  63296.0    44
# ...

# %%
from census import Census
import pandas as pd

# Initialize with your API key
c = Census("API KEY")

# Fetching a variety of data for a state, for example, California (state code 06)
data = c.acs5.state(('NAME', 
                     'B01003_001E',  # Total population
                     'B19013_001E',  # Median household income
                     'B25077_001E',  # Median housing value
                     'B23025_005E'), # Unemployment count
                     states.CA.fips, year=2019)

# Convert to DataFrame
df = pd.DataFrame(data)

# Rename columns for clarity
df.rename(columns={'NAME': 'State', 'B01003_001E': 'Total Population', 
                   'B19013_001E': 'Median Household Income', 
                   'B25077_001E': 'Median Housing Value',
                   'B23025_005E': 'Unemployment Count'}, inplace=True)

print(df)

# %%
income_df2018
# Out:
#                    State  Median Household Income state
# 0            Mississippi                  43567.0    28
# 1               Missouri                  53560.0    29
# 2                Montana                  52559.0    30
# 3               Nebraska                  59116.0    31
# 4                 Nevada                  57598.0    32
# 5          New Hampshire                  74057.0    33
# 6             New Jersey                  79363.0    34
# 7             New Mexico                  48059.0    35
# 8               New York                  65323.0    36
# 9         North Carolina                  52413.0    37
# 10          North Dakota                  63473.0    38
# 11                  Ohio                  54533.0    39
# 12              Oklahoma                  51424.0    40
# 13                Oregon                  59393.0    41
# 14          Pennsylvania                  59445.0    42
# 15          Rhode Island                  63296.0    44
# ...
